# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
else:
    # find the repo root from wherever this kernel started
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")
# Out:
# Working dir: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# Starter data found. You're ready.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Refresh Opportunity
#
# I chose the Refresh Opportunity lane because I want to investigate which pages may be worth prioritizing for human content review. I am interested in understanding how search demand and performance signals work together to identify pages that may need attention. This could help a content team focus its limited time on pages that appear to have a meaningful opportunity rather than manually reviewing every page.

# %%
print("Selected lane: Refresh Opportunity")
print("Goal: Prioritize pages for human content review using search demand and performance signals.")
# Out:
# Selected lane: Refresh Opportunity
# Goal: Prioritize pages for human content review using search demand and performance signals.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Research question:** Can search demand and performance signals help prioritize pages for human content review?
#
# **Decision:** The goal is to decide which pages should be investigated first by the content team.
#
# **Action:** The team can investigate the prioritized pages and then decide whether to refresh, update, monitor, or leave the content as it is.
#
# **Cost of a wrong recommendation:** Prioritizing a poor candidate could waste the content team's limited time and effort. On the other hand, failing to prioritize a valuable page could mean missing a potential opportunity to improve its performance.
#
# **Why data/ML can help:** The dataset contains 30,000 content records and many signals for each record. Manually investigating every page would take considerable time. Data analysis can help identify useful patterns and narrow down the pages worth human investigation. ML may be useful later if the analysis shows that it can improve this prioritization.

# %%
print("Number of content records:", len(df))
print("Number of features:", len(df.columns))
# Out:
# Number of content records: 30000
# Number of features: 44

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains **30,000 content records and 44 columns**, which makes manual investigation of every record impractical.
#
# The median `trend_pct` is **-33.5%**, showing that declining performance is a notable pattern in this dataset.
#
# Search demand varies substantially: the median `search_volume` is **10**, while the maximum is **74,000**. This suggests that a decline may have different importance depending on the search demand of the page.
#
# These observations make it worth investigating whether demand and performance signals can help prioritize pages for human review.

# %%
import pandas as pd, numpy as np
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Number of records:", len(df))
print("Number of columns:", len(df.columns))

print("Median trend_pct:", df['trend_pct'].median())
print("Median search_volume:", df['search_volume'].median())
print("Maximum search_volume:", df['search_volume'].max())

df[['search_volume', 'trend_pct', 'days_since_last_update', 'ctr', 'avg_position']].describe()
# Out:
# Number of records: 30000
# Number of columns: 44
# Median trend_pct: -33.5
# Median search_volume: 10.0
# Maximum search_volume: 74000.0
#        search_volume     trend_pct  days_since_last_update           ctr  \
# count   27532.000000  26612.000000            30000.000000  30000.000000
# mean      158.882391     -4.785969               46.098300      0.510733
# std      1518.270825    473.861780               42.078709      3.279162
# min         0.000000   -100.000000                1.000000      0.000000
# 25%         0.000000    -62.600000               20.000000      0.000000
# 50%        10.000000    -33.500000               20.000000      0.070000
# 75%        20.000000      0.000000              104.000000      0.290000
# max     74000.000000  44900.000000              373.000000    100.000000
#
#        avg_position
# count   30000.00000
# mean       16.34238
# std        15.21679
# min         0.00000
# 25%         6.20000
# 50%        10.80000
# 75%        22.30000
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **What I can claim:**
#
# I can use this dataset to observe patterns and relationships between search demand, performance signals, and content records. I can investigate whether certain combinations of signals appear useful for prioritizing pages for human review. Any findings will be treated as observational and directional rather than as proof.
#
# **What I cannot claim:**
#
# I cannot claim that a page definitely needs a refresh based only on these signals. I also cannot claim that refreshing a page will cause its performance to improve, because the available data does not establish causality. I cannot claim that these patterns represent Google's ranking algorithm or predict exactly how Google will rank a page.

# %%
signals = [
    'search_volume',
    'trend_pct',
    'ctr',
    'avg_position',
    'engagement_rate'
]

print("Signals considered for investigation:")
for signal in signals:
    print("-", signal)
# Out:
# Signals considered for investigation:
# - search_volume
# - trend_pct
# - ctr
# - avg_position
# - engagement_rate

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
